# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(12, 6))

# %%
graph1 = fig.add_subplot(2, 2, 1)
graph2 = fig.add_subplot(2, 2, 2)

# %%
x = range(0, 10)
y = [num**2 for num in x]

# %%
graph1.plot(x, y)
graph2.bar(x, y)
# Out:
# <BarContainer object of 10 artists>

# %%
fig

# %%
x = np.arange(0.0, 2*np.pi, 0.1)
sin_y = np.sin(x)
cos_y = np.cos(x)

# %%
fig2 = plt.figure()
fig2_sub1 = fig2.add_subplot(2, 1, 1)
fig2_sub2 = fig2.add_subplot(2, 1, 2)

# %%
fig2_sub1.plot(x, sin_y, 'b:')
fig2_sub2.plot(x, cos_y, 'r:')

# %%
fig2

# %%
fig4, graphs = plt.subplots(3, 3, figsize=(12, 6))

# %%
graphs[2][1]
# Out:
# <AxesSubplot:>

# %%
fig = plt.figure()
graph = fig.add_subplot(1, 1, 1)
graph.plot(np.random.randn(1000).cumsum())

# %%
graph.set_xticks([0, 500, 1000])
graph.set_yticks([0, 30, 70])

# %%
fig

# %%
graph.set_xlabel('Range')
graph.set_ylabel('Level')
# Out:
# Text(3.1999999999999993, 0.5, 'Level')

# %%
graph.set_title('Plot title')
# Out:
# Text(0.5, 1.0, 'Plot title')

# %%
fig
