# %%
import json # import json module

# with statement
with open('data/v01050.json', encoding="utf-8") as json_file:
    json_data = json.load(json_file)

# %%
json_data
# Out:
# {'TEST': {'TSTNO': '1050',
#   'VERNO': '2 ',
#   'TITLE': '1987 BUICK LESABRE INTO FRONTAL BARRIER',
#   'TSTOBJ': '30 MPH FRONTAL BARRIER IMPACT 208,212,219(PARTIAL,& 301-75 COMPLIANCE ',
#   'TSTDAT': '13-JUL-87',
#   'TSTPRFD': 'TRC OF OHIO',
#   'CONNO': 'DTNH22-87-C-01024',
#   'TSTREF': '870713',
#   'TSTTYPD': 'FMVSS 208 OCCUPANT CRASH PROTECTION',
#   'TSTCFND': 'VEHICLE INTO BARRIER',
#   'TKSURFD': 'CONCRETE',
#   'TKCOND': 'DRY',
#   'TEMP': '31',
#   'RECTYPD': 'FM MULTIPLEXOR TAPE RECORDER',
#   'LINK': 'UMB',
#   'CLSSPD': '47.5',
#   'IMPANG': '0',
#   'OFFSET': '0',
#   'IMPPNT': '',
#   'MEASURD': 'ENGLISH',
#   'TOTCRV': '23',
#   'TSTCOM': 'NO COMMENTS'},
#  'VEHICLE': [{'VEHNO': '1',
#    'MAKED': 'BUICK',
#    'MODELD': 'LESABRE',
#    'YEAR': '1987',
#    'BODYD': 'TWO DOOR SEDAN',
#    'VIN': '1G4HP1437HH454361',
#    'ENGINED': 'STRAIGHT 6 TRANSVERSE FRONT',
#    'ENGDSP': '3.8',
#    'TRANSMD': 'AUTOMATIC - FRONT WHEEL DRIVE',
#    'VEHTWT': '1693',
#    'WHLBAS': '2817',
#    'VEHLEN': '4999',
#    'VEHWID': '1819',
#    'VEHCG': '1143',
#    'STRSEPD': 'UNKNOWN',
#    'COLMECD': 'NOT APPLICABLE',
#    'MODINDD': 'PRODUCTION VEHICLE',
#    'MODDSC': 'NO COMMENTS ',
#    'BX1': '4999',
#    'BX2': '4397',
#    'BX3': '3736',
#    'BX4': '3320',
#    'BX5': '3322',
#    'BX6': '3322',
#    'BX7': '3312',
#    'BX8': '1928',
#    'BX9': '1928',
#    'BX10': '1905',
#    'BX11': '1902',
#    'BX12': '3297',
#    'BX13': '3292',
#    'BX14': '3571',
#    'BX15': '3637',
#    'BX16': '2883',
#    'BX17': '381',
#    'BX18': '422',
#    'BX19': '4877',
#    'BX20': '4872',
#    'BX21': '572',
#    'VEHSPD': '47.5',
#    'CRBANG': '0',
#    'PDOF': '0',
#    'BMPENGD': 'NOT APPLICABLE',
#    'SILENGD': 'NOT APPLICABLE',
#    'APLENGD': 'NOT APPLICABLE',
#    'DPD1': '617',
#    'DPD2': '660',
#    'DPD3': '650',
#    'DPD4': '688',
#    'DPD5': '663',
#    'DPD6': '622',
#    'VDI': '12FDEW3',
#    'LENCNT': '1666',
#    'DAMDST': '0',
#    'CRHDST': '693',
#    'AX1': '4305',
#    'AX2': '4176',
#    'AX3': '3696',
#    'AX4': '3325',
#    'AX5': '3325',
#    'AX6': '3315',
#    'AX7': '3307',
#    'AX8': '1930',
#    'AX9': '1933',
#    'AX10': '1905',
#    'AX11': '1900',
#    'AX12': '3272',
#    'AX13': '3279',
#    'AX14': '3533',
#    'AX15': '3607',
#    'AX16': '2873',
#    'AX17': '361',
#    'AX18': '401',
#    'AX19': '4255',
#    'AX20': '4255',
#    'AX21': '572',
#    'CARANG': '',
#    'VEHOR': '',
#    'VEHCOM': "STEERING COLUMN COLLAPSE MECHANISM UNDER DASH, COULDN'T BE SEEN"}],
#  'BARRIER': {'BARRIGD': 'RIGID',
#   'BARSHPD': 'FLAT BARRIER',
#   'BARANG': '0',
#   'BARDIA': '',
#   'BARID': '',
#   'BARCOM': 'NO COMMENTS'},
#  'OCCUPANT': [{'OCCLOC': '01',
#    'VEHNO': '1',
#    'OCCTYPD': 'PART 572 DUMMY',
#    'OCCAGE': '',
#    'OCCSEXD': 'MALE',
#    'OCCHT': '',
#    'OCCWT': '',
#    'MTHCALD': 'PART 572',
#    'DUMSIZD': '50 PERCENTILE',
#    'DUMMAN': 'MFG: ALDERSON RESEARCH LABS; S/N 758 ',
#    'DUMMOD': 'UNMODIFIED ',
#    'DUMDSC': 'PART 572B CALIBRATION ',
#    'HH': '434',
#    'HW': '564',
#    'HR': '224',
#    'HS': '318',
#    'CD': '640',
#    'CS': '396',
#    'AD': '168',
#    'HD': '140',
#    'KD': '140',
#    'HB': '',
#    'NB': '',
#    'CB': '',
#    'KB': '',
#    'SEPOSN': 'CN',
#    'CNTRH1D': 'STEERING WHEEL',
#    'CNTRH2D': 'NONE',
#    'CNTRC1D': 'STEERING WHEEL',
#    'CNTRC2D': 'NONE',
#    'CNTRL1D': 'DASHPANEL',
#    'CNTRL2D': 'NONE',
#    'HIC': '664',
#    'T1': '86.75',
#    'T2': '121.13',
#    'CLIP3M': '35.1',
#    'LFEM': '-5009',
#    'RFEM': '-3928',
#    'CSI': '218',
#    'LBELT': '',
#    'SBELT': '',
#    'TTI': '',
#    'PELVG': '',
#    'OCCCOM': 'NO COMMENTS'},
#   {'OCCLOC': '02',
#    'VEHNO': '1',
#    'OCCTYPD': 'PART 572 DUMMY',
#    'OCCAGE': '',
#    'OCCSEXD': 'MALE',
#    'OCCHT': '',
#    'OCCWT': '',
#    'MTHCALD': 'PART 572',
#    'DUMSIZD': '50 PERCENTILE',
#    'DUMMAN': 'MFG: ALDERSON RESEARCH LABS; S/N 690 ',
#    'DUMMOD': 'UNMODIFIED ',
#    'DUMDSC': 'PART 572B CALIBRATION ',
#    'HH': '442',
#    'HW': '599',
#    'HR': '193',
#    'HS': '300',
#    'CD': '577',
#    'CS': '',
#    'AD': '142',
#    'HD': '122',
#    'KD': '191',
#    'HB': '',
#    'NB': '',
#    'CB': '',
#    'KB': '',
#    'SEPOSN': 'CN',
#    'CNTRH1D': 'NONE',
#    'CNTRH2D': 'NONE',
#    'CNTRC1D': 'NONE',
#    'CNTRC2D': 'NONE',
#    'CNTRL1D': 'DASHPANEL',
#    'CNTRL2D': 'NONE',
#    'HIC': '366',
#    'T1': '96.38',
#    'T2': '132.38',
#    'CLIP3M': '29.8',
#    'LFEM': '-3261',
#    'RFEM': '-2700',
#    'CSI': '212',
#    'LBELT': '',
#    'SBELT': '',
#    'TTI': '',
#    'PELVG': '',
#    'OCCCOM': 'NO COMMENTS'}],
#  'RESTRAINT': [{'RSTNO': '1',
#    'VEHNO': '1',
#    'OCCLOCD': 'LEFT FRONT SEAT',
#    'RSTTYPD': 'PASSIVE 3 POINT BELT',
#    'RSTMNTD': '',
#    'DEPLOYD': 'NOT APPLICABLE',
#    'RSTCOM': 'NO COMMENTS '},
#   {'RSTNO': '1',
#    'VEHNO': '1',
#    'OCCLOCD': 'RIGHT FRONT SEAT',
#    'RSTTYPD': 'PASSIVE 3 POINT BELT',
#    'RSTMNTD': '',
#    'DEPLOYD': 'NOT APPLICABLE',
#    'RSTCOM': 'NO COMMENTS '},
#   {'RSTNO': '2',
#    'VEHNO': '1',
#    'OCCLOCD': 'RIGHT FRONT SEAT',
#    'RSTTYPD': 'DASHPANEL',
#    'RSTMNTD': '',
#    'DEPLOYD': 'NOT APPLICABLE',
#    'RSTCOM': 'NO COMMENTS '}],
#  'URL': {'URL_UDS': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=&database=v&name=v01050&format=uds',
#   'URL_EV5': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=&database=v&name=v01050&format=ev5',
#   'URL_ABF': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=&database=v&name=v01050&format=abf',
#   'URL_ISO': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=&database=v&name=v01050&format=iso',
#   'URL_TDMS': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=&database=v&name=v01050&format=tdms'},
#  'INSTRUMENTATION': [{'CURVE': '1',
#    'TSTNO': '1050',
#    'VEHNO': '1',
#    'SENTYPD': 'ACCELEROMETER',
#    'SENLOCD': 'LEFT FRONT SEAT',
#    'SENATTD': 'HEAD CG',
#    'AXISD': 'X - LOCAL',
#    'XUNITSD': 'SECONDS',
#    'YUNITSD': "G'S",
#    'PREFIL': '1650',
#    'PREMAX': '32.3339',
#    'PREMIN': '-110.537',
#    'INSMAN': 'MFG:ENDEVCO                     S/N:BY27J       MDL:7264 ',
#    'CALDAT': '14-APR-87',
#    'INSRAT': '466',
#    'CHLMAX': '24',
#    'INIVEL': '47.5',
#    'NFP': '-160',
#    'NLP': '2721',
#    'DELT': '125',
#    'DASTAT': 'AM',
#    'SCFCTR': '1',
#    'CHSTATD': 'PRIMARY',
#    'INSCOM': 'NO COMMENTS',
#    'XTYPE': 'TIME',
#    'YTYPE': 'ACCELERATION',
#    'SIGNALNAME': 'v01050_001aa0.uds',
#    'URL_UDS': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=1&database=v&name=v01050_001aa0.uds&format=uds_single',
#    'URL_TSV': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=1&database=v&name=v01050_001aa0.uds&format=tsv_single'},
#   {'CURVE': '2',
#    'TSTNO': '1050',
#    'VEHNO': '1',
#    'SENTYPD': 'ACCELEROMETER',
#    'SENLOCD': 'LEFT FRONT SEAT',
#    'SENATTD': 'HEAD CG',
#    'AXISD': 'Y - LOCAL',
#    'XUNITSD': 'SECONDS',
#    'YUNITSD': "G'S",
#    'PREFIL': '1650',
#    'PREMAX': '36.5295',
#    'PREMIN': '-10.0741',
#    'INSMAN': 'MFG:ENDEVCO                     S/N:BI18J       MDL:7264 ',
#    'CALDAT': '14-APR-87',
#    'INSRAT': '444',
#    'CHLMAX': '8',
#    'INIVEL': '0',
#    'NFP': '-160',
#    'NLP': '2721',
#    'DELT': '125',
#    'DASTAT': 'AM',
#    'SCFCTR': '1',
#    'CHSTATD': 'PRIMARY',
#    'INSCOM': 'NO COMMENTS',
#    'XTYPE': 'TIME',
#    'YTYPE': 'ACCELERATION',
#    'SIGNALNAME': 'v01050_002aa0.uds',
#    'URL_UDS': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=2&database=v&name=v01050_002aa0.uds&format=uds_single',
#    'URL_TSV': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=2&database=v&name=v01050_002aa0.uds&format=tsv_single'},
#   {'CURVE': '3',
#    'TSTNO': '1050',
#    'VEHNO': '1',
#    'SENTYPD': 'ACCELEROMETER',
#    'SENLOCD': 'LEFT FRONT SEAT',
#    'SENATTD': 'HEAD CG',
#    'AXISD': 'Z - LOCAL',
#    'XUNITSD': 'SECONDS',
#    'YUNITSD': "G'S",
#    'PREFIL': '1650',
#    'PREMAX': '15.8832',
#    'PREMIN': '-86.5231',
#    'INSMAN': 'MFG:ENDEVCO                     S/N:BP89J       MDL:7264 ',
#    'CALDAT': '14-APR-87',
#    'INSRAT': '459',
#    'CHLMAX': '19',
#    'INIVEL': '0',
#    'NFP': '-160',
#    'NLP': '2721',
#    'DELT': '125',
#    'DASTAT': 'AM',
#    'SCFCTR': '1',
#    'CHSTATD': 'PRIMARY',
#    'INSCOM': 'NO COMMENTS',
#    'XTYPE': 'TIME',
#    'YTYPE': 'ACCELERATION',
#    'SIGNALNAME': 'v01050_003aa0.uds',
#    'URL_UDS': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=3&database=v&name=v01050_003aa0.uds&format=uds_single',
#    'URL_TSV': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=3&database=v&name=v01050_003aa0.uds&format=tsv_single'},
#   {'CURVE': '4',
#    'TSTNO': '1050',
#    'VEHNO': '1',
#    'SENTYPD': 'ACCELEROMETER',
#    'SENLOCD': 'LEFT FRONT SEAT',
#    'SENATTD': 'CHEST',
#    'AXISD': 'X - LOCAL',
#    'XUNITSD': 'SECONDS',
#    'YUNITSD': "G'S",
#    'PREFIL': '1650',
#    'PREMAX': '8.2487',
#    'PREMIN': '-38.473',
#    'INSMAN': 'MFG:ENDEVCO                     S/N:BI08J       MDL:7264 ',
#    'CALDAT': '14-APR-87',
#    'INSRAT': '439',
#    'CHLMAX': '9',
#    'INIVEL': '47.5',
#    'NFP': '-160',
#    'NLP': '2721',
#    'DELT': '125',
#    'DASTAT': 'AM',
#    'SCFCTR': '1',
#    'CHSTATD': 'PRIMARY',
#    'INSCOM': 'NO COMMENTS',
#    'XTYPE': 'TIME',
#    'YTYPE': 'ACCELERATION',
#    'SIGNALNAME': 'v01050_004aa0.uds',
#    'URL_UDS': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=4&database=v&name=v01050_004aa0.uds&format=uds_single',
#    'URL_TSV': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=4&database=v&name=v01050_004aa0.uds&format=tsv_single'},
#   {'CURVE': '5',
#    'TSTNO': '1050',
#    'VEHNO': '1',
#    'SENTYPD': 'ACCELEROMETER',
#    'SENLOCD': 'LEFT FRONT SEAT',
#    'SENATTD': 'CHEST',
#    'AXISD': 'Y - LOCAL',
#    'XUNITSD': 'SECONDS',
#    'YUNITSD': "G'S",
#    'PREFIL': '1650',
#    'PREMAX': '13.0851',
#    'PREMIN': '-6.36484',
#    'INSMAN': 'MFG:ENDEVCO                     S/N:BG58J       MDL:7264 ',
#    'CALDAT': '14-APR-87',
#    'INSRAT': '480',
#    'CHLMAX': '3',
#    'INIVEL': '0',
#    'NFP': '-160',
#    'NLP': '2721',
#    'DELT': '125',
#    'DASTAT': 'AM',
#    'SCFCTR': '1',
#    'CHSTATD': 'PRIMARY',
#    'INSCOM': 'NO COMMENTS',
#    'XTYPE': 'TIME',
#    'YTYPE': 'ACCELERATION',
#    'SIGNALNAME': 'v01050_005aa0.uds',
#    'URL_UDS': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=5&database=v&name=v01050_005aa0.uds&format=uds_single',
#    'URL_TSV': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=5&database=v&name=v01050_005aa0.uds&format=tsv_single'},
#   {'CURVE': '6',
#    'TSTNO': '1050',
#    'VEHNO': '1',
#    'SENTYPD': 'ACCELEROMETER',
#    'SENLOCD': 'LEFT FRONT SEAT',
#    'SENATTD': 'CHEST',
#    'AXISD': 'Z - LOCAL',
#    'XUNITSD': 'SECONDS',
#    'YUNITSD': "G'S",
#    'PREFIL': '1650',
#    'PREMAX': '13.1454',
#    'PREMIN': '-12.9831',
#    'INSMAN': 'MFG:ENDEVCO                     S/N:BY88J       MDL:7264 ',
#    'CALDAT': '14-APR-87',
#    'INSRAT': '446',
#    'CHLMAX': '3',
#    'INIVEL': '0',
#    'NFP': '-160',
#    'NLP': '2721',
#    'DELT': '125',
#    'DASTAT': 'AM',
#    'SCFCTR': '1',
#    'CHSTATD': 'PRIMARY',
#    'INSCOM': 'NO COMMENTS',
#    'XTYPE': 'TIME',
#    'YTYPE': 'ACCELERATION',
#    'SIGNALNAME': 'v01050_006aa0.uds',
#    'URL_UDS': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=6&database=v&name=v01050_006aa0.uds&format=uds_single',
#    'URL_TSV': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=6&database=v&name=v01050_006aa0.uds&format=tsv_single'},
#   {'CURVE': '7',
#    'TSTNO': '1050',
#    'VEHNO': '1',
#    'SENTYPD': 'LOAD CELL',
#    'SENLOCD': 'LEFT FRONT SEAT',
#    'SENATTD': 'FEMUR - LEFT',
#    'AXISD': 'Z - LOCAL',
#    'XUNITSD': 'SECONDS',
#    'YUNITSD': 'NEWTONS',
#    'PREFIL': '1650',
#    'PREMAX': '361.392',
#    'PREMIN': '-5105.8',
#    'INSMAN': 'MFG:GSE                         S/N:718         MDL:2430 ',
#    'CALDAT': '14-APR-87',
#    'INSRAT': '3000',
#    'CHLMAX': '38',
#    'INIVEL': '0',
#    'NFP': '-160',
#    'NLP': '2721',
#    'DELT': '125',
#    'DASTAT': 'AM',
#    'SCFCTR': '1',
#    'CHSTATD': 'PRIMARY',
#    'INSCOM': 'NO COMMENTS',
#    'XTYPE': 'TIME',
#    'YTYPE': 'FORCE',
#    'SIGNALNAME': 'v01050_007fa0.uds',
#    'URL_UDS': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=7&database=v&name=v01050_007fa0.uds&format=uds_single',
#    'URL_TSV': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=7&database=v&name=v01050_007fa0.uds&format=tsv_single'},
#   {'CURVE': '8',
#    'TSTNO': '1050',
#    'VEHNO': '1',
#    'SENTYPD': 'LOAD CELL',
#    'SENLOCD': 'LEFT FRONT SEAT',
#    'SENATTD': 'FEMUR - RIGHT',
#    'AXISD': 'Z - LOCAL',
#    'XUNITSD': 'SECONDS',
#    'YUNITSD': 'NEWTONS',
#    'PREFIL': '1650',
#    'PREMAX': '576.045',
#    'PREMIN': '-4030.83',
#    'INSMAN': 'MFG:GSE                         S/N:756         MDL:2430 ',
#    'CALDAT': '14-APR-87',
#    'INSRAT': '3000',
#    'CHLMAX': '30',
#    'INIVEL': '0',
#    'NFP': '-160',
#    'NLP': '2721',
#    'DELT': '125',
#    'DASTAT': 'AM',
#    'SCFCTR': '1',
#    'CHSTATD': 'PRIMARY',
#    'INSCOM': 'NO COMMENTS',
#    'XTYPE': 'TIME',
#    'YTYPE': 'FORCE',
#    'SIGNALNAME': 'v01050_008fa0.uds',
#    'URL_UDS': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=8&database=v&name=v01050_008fa0.uds&format=uds_single',
#    'URL_TSV': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=8&database=v&name=v01050_008fa0.uds&format=tsv_single'},
#   {'CURVE': '9',
#    'TSTNO': '1050',
#    'VEHNO': '1',
#    'SENTYPD': 'ACCELEROMETER',
#    'SENLOCD': 'RIGHT FRONT SEAT',
#    'SENATTD': 'HEAD CG',
#    'AXISD': 'X - LOCAL',
#    'XUNITSD': 'SECONDS',
#    'YUNITSD': "G'S",
#    'PREFIL': '1650',
#    'PREMAX': '60.0076',
#    'PREMIN': '-35.6677',
#    'INSMAN': 'MFG:ENDEVCO                     S/N:BF61J       MDL:7264 ',
#    'CALDAT': '14-APR-87',
#    'INSRAT': '421',
#    'CHLMAX': '14',
#    'INIVEL': '47.5',
#    'NFP': '-160',
#    'NLP': '2721',
#    'DELT': '125',
#    'DASTAT': 'AM',
#    'SCFCTR': '1',
#    'CHSTATD': 'PRIMARY',
#    'INSCOM': 'NO COMMENTS',
#    'XTYPE': 'TIME',
#    'YTYPE': 'ACCELERATION',
#    'SIGNALNAME': 'v01050_009aa0.uds',
#    'URL_UDS': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=9&database=v&name=v01050_009aa0.uds&format=uds_single',
#    'URL_TSV': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=9&database=v&name=v01050_009aa0.uds&format=tsv_single'},
#   {'CURVE': '10',
#    'TSTNO': '1050',
#    'VEHNO': '1',
#    'SENTYPD': 'ACCELEROMETER',
#    'SENLOCD': 'RIGHT FRONT SEAT',
#    'SENATTD': 'HEAD CG',
#    'AXISD': 'Y - LOCAL',
#    'XUNITSD': 'SECONDS',
#    'YUNITSD': "G'S",
#    'PREFIL': '1650',
#    'PREMAX': '11.3718',
#    'PREMIN': '-8.55844',
#    'INSMAN': 'MFG:ENDEVCO                     S/N:BW31J       MDL:7264 ',
#    'CALDAT': '14-APR-87',
#    'INSRAT': '378',
#    'CHLMAX': '3',
#    'INIVEL': '0',
#    'NFP': '-160',
#    'NLP': '2721',
#    'DELT': '125',
#    'DASTAT': 'AM',
#    'SCFCTR': '1',
#    'CHSTATD': 'PRIMARY',
#    'INSCOM': 'NO COMMENTS',
#    'XTYPE': 'TIME',
#    'YTYPE': 'ACCELERATION',
#    'SIGNALNAME': 'v01050_010aa0.uds',
#    'URL_UDS': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=10&database=v&name=v01050_010aa0.uds&format=uds_single',
#    'URL_TSV': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=10&database=v&name=v01050_010aa0.uds&format=tsv_single'},
#   {'CURVE': '11',
#    'TSTNO': '1050',
#    'VEHNO': '1',
#    'SENTYPD': 'ACCELEROMETER',
#    'SENLOCD': 'RIGHT FRONT SEAT',
#    'SENATTD': 'HEAD CG',
#    'AXISD': 'Z - LOCAL',
#    'XUNITSD': 'SECONDS',
#    'YUNITSD': "G'S",
#    'PREFIL': '1650',
#    'PREMAX': '7.30156',
#    'PREMIN': '-41.5873',
#    'INSMAN': 'MFG:ENDEVCO                     S/N:BP26J       MDL:7264 ',
#    'CALDAT': '14-APR-87',
#    'INSRAT': '478',
#    'CHLMAX': '9',
#    'INIVEL': '0',
#    'NFP': '-160',
#    'NLP': '2721',
#    'DELT': '125',
#    'DASTAT': 'AM',
#    'SCFCTR': '1',
#    'CHSTATD': 'PRIMARY',
#    'INSCOM': 'NO COMMENTS',
#    'XTYPE': 'TIME',
#    'YTYPE': 'ACCELERATION',
#    'SIGNALNAME': 'v01050_011aa0.uds',
#    'URL_UDS': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=11&database=v&name=v01050_011aa0.uds&format=uds_single',
#    'URL_TSV': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=11&database=v&name=v01050_011aa0.uds&format=tsv_single'},
#   {'CURVE': '12',
#    'TSTNO': '1050',
#    'VEHNO': '1',
#    'SENTYPD': 'ACCELEROMETER',
#    'SENLOCD': 'RIGHT FRONT SEAT',
#    'SENATTD': 'CHEST',
#    'AXISD': 'X - LOCAL',
#    'XUNITSD': 'SECONDS',
#    'YUNITSD': "G'S",
#    'PREFIL': '1650',
#    'PREMAX': '9.20627',
#    'PREMIN': '-37.4339',
#    'INSMAN': 'MFG:ENDEVCO                     S/N:BY51J       MDL:7264 ',
#    'CALDAT': '14-APR-87',
#    'INSRAT': '386',
#    'CHLMAX': '10',
#    'INIVEL': '47.5',
#    'NFP': '-160',
#    'NLP': '2721',
#    'DELT': '125',
#    'DASTAT': 'AM',
#    'SCFCTR': '1',
#    'CHSTATD': 'PRIMARY',
#    'INSCOM': 'NO COMMENTS',
#    'XTYPE': 'TIME',
#    'YTYPE': 'ACCELERATION',
#    'SIGNALNAME': 'v01050_012aa0.uds',
#    'URL_UDS': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=12&database=v&name=v01050_012aa0.uds&format=uds_single',
#    'URL_TSV': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=12&database=v&name=v01050_012aa0.uds&format=tsv_single'},
#   {'CURVE': '13',
#    'TSTNO': '1050',
#    'VEHNO': '1',
#    'SENTYPD': 'ACCELEROMETER',
#    'SENLOCD': 'RIGHT FRONT SEAT',
#    'SENATTD': 'CHEST',
#    'AXISD': 'Y - LOCAL',
#    'XUNITSD': 'SECONDS',
#    'YUNITSD': "G'S",
#    'PREFIL': '1650',
#    'PREMAX': '29.7306',
#    'PREMIN': '-21.3185',
#    'INSMAN': 'MFG:ENDEVCO                     S/N:BY01J       MDL:7264 ',
#    'CALDAT': '14-APR-87',
#    'INSRAT': '388',
#    'CHLMAX': '8',
#    'INIVEL': '0',
#    'NFP': '-160',
#    'NLP': '2721',
#    'DELT': '125',
#    'DASTAT': 'AM',
#    'SCFCTR': '1',
#    'CHSTATD': 'PRIMARY',
#    'INSCOM': 'NO COMMENTS',
#    'XTYPE': 'TIME',
#    'YTYPE': 'ACCELERATION',
#    'SIGNALNAME': 'v01050_013aa0.uds',
#    'URL_UDS': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=13&database=v&name=v01050_013aa0.uds&format=uds_single',
#    'URL_TSV': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=13&database=v&name=v01050_013aa0.uds&format=tsv_single'},
#   {'CURVE': '14',
#    'TSTNO': '1050',
#    'VEHNO': '1',
#    'SENTYPD': 'ACCELEROMETER',
#    'SENLOCD': 'RIGHT FRONT SEAT',
#    'SENATTD': 'CHEST',
#    'AXISD': 'Z - LOCAL',
#    'XUNITSD': 'SECONDS',
#    'YUNITSD': "G'S",
#    'PREFIL': '1650',
#    'PREMAX': '23.1316',
#    'PREMIN': '-6.64204',
#    'INSMAN': 'MFG:ENDEVCO                     S/N:BF71J       MDL:7264 ',
#    'CALDAT': '14-APR-87',
#    'INSRAT': '431',
#    'CHLMAX': '5',
#    'INIVEL': '0',
#    'NFP': '-160',
#    'NLP': '2721',
#    'DELT': '125',
#    'DASTAT': 'AM',
#    'SCFCTR': '1',
#    'CHSTATD': 'PRIMARY',
#    'INSCOM': 'NO COMMENTS',
#    'XTYPE': 'TIME',
#    'YTYPE': 'ACCELERATION',
#    'SIGNALNAME': 'v01050_014aa0.uds',
#    'URL_UDS': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=14&database=v&name=v01050_014aa0.uds&format=uds_single',
#    'URL_TSV': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=14&database=v&name=v01050_014aa0.uds&format=tsv_single'},
#   {'CURVE': '15',
#    'TSTNO': '1050',
#    'VEHNO': '1',
#    'SENTYPD': 'LOAD CELL',
#    'SENLOCD': 'RIGHT FRONT SEAT',
#    'SENATTD': 'FEMUR - LEFT',
#    'AXISD': 'Z - LOCAL',
#    'XUNITSD': 'SECONDS',
#    'YUNITSD': 'NEWTONS',
#    'PREFIL': '1650',
#    'PREMAX': '559.644',
#    'PREMIN': '-3374.84',
#    'INSMAN': 'MFG:GSE                         S/N:721         MDL:2430 ',
#    'CALDAT': '14-APR-87',
#    'INSRAT': '2869',
#    'CHLMAX': '26',
#    'INIVEL': '0',
#    'NFP': '-160',
#    'NLP': '2721',
#    'DELT': '125',
#    'DASTAT': 'AM',
#    'SCFCTR': '1',
#    'CHSTATD': 'PRIMARY',
#    'INSCOM': 'NO COMMENTS',
#    'XTYPE': 'TIME',
#    'YTYPE': 'FORCE',
#    'SIGNALNAME': 'v01050_015fa0.uds',
#    'URL_UDS': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=15&database=v&name=v01050_015fa0.uds&format=uds_single',
#    'URL_TSV': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=15&database=v&name=v01050_015fa0.uds&format=tsv_single'},
#   {'CURVE': '16',
#    'TSTNO': '1050',
#    'VEHNO': '1',
#    'SENTYPD': 'LOAD CELL',
#    'SENLOCD': 'RIGHT FRONT SEAT',
#    'SENATTD': 'FEMUR - RIGHT',
#    'AXISD': 'Z - LOCAL',
#    'XUNITSD': 'SECONDS',
#    'YUNITSD': 'NEWTONS',
#    'PREFIL': '1650',
#    'PREMAX': '1374.88',
#    'PREMIN': '-2816.8',
#    'INSMAN': 'MFG:GSE                         S/N:744         MDL:2430 ',
#    'CALDAT': '14-APR-87',
#    'INSRAT': '3000',
#    'CHLMAX': '21',
#    'INIVEL': '0',
#    'NFP': '-160',
#    'NLP': '2721',
#    'DELT': '125',
#    'DASTAT': 'AM',
#    'SCFCTR': '1',
#    'CHSTATD': 'PRIMARY',
#    'INSCOM': 'NO COMMENTS',
#    'XTYPE': 'TIME',
#    'YTYPE': 'FORCE',
#    'SIGNALNAME': 'v01050_016fa0.uds',
#    'URL_UDS': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=16&database=v&name=v01050_016fa0.uds&format=uds_single',
#    'URL_TSV': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=16&database=v&name=v01050_016fa0.uds&format=tsv_single'},
#   {'CURVE': '17',
#    'TSTNO': '1050',
#    'VEHNO': '1',
#    'SENTYPD': 'ACCELEROMETER',
#    'SENLOCD': 'NOT APPLICABLE',
#    'SENATTD': 'SEAT - LEFT REAR',
#    'AXISD': 'X - GLOBAL',
#    'XUNITSD': 'SECONDS',
#    'YUNITSD': "G'S",
#    'PREFIL': '1650',
#    'PREMAX': '18.9325',
#    'PREMIN': '-45.1877',
#    'INSMAN': 'MFG:ENDEVCO                     S/N:BP29J       MDL:7264 ',
#    'CALDAT': '14-APR-87',
#    'INSRAT': '398',
#    'CHLMAX': '11',
#    'INIVEL': '47.5',
#    'NFP': '-160',
#    'NLP': '2721',
#    'DELT': '125',
#    'DASTAT': 'AM',
#    'SCFCTR': '1',
#    'CHSTATD': 'PRIMARY',
#    'INSCOM': 'NO COMMENTS',
#    'XTYPE': 'TIME',
#    'YTYPE': 'ACCELERATION',
#    'SIGNALNAME': 'v01050_017aa0.uds',
#    'URL_UDS': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=17&database=v&name=v01050_017aa0.uds&format=uds_single',
#    'URL_TSV': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=17&database=v&name=v01050_017aa0.uds&format=tsv_single'},
#   {'CURVE': '18',
#    'TSTNO': '1050',
#    'VEHNO': '1',
#    'SENTYPD': 'ACCELEROMETER',
#    'SENLOCD': 'NOT APPLICABLE',
#    'SENATTD': 'SEAT - RIGHT REAR',
#    'AXISD': 'X - GLOBAL',
#    'XUNITSD': 'SECONDS',
#    'YUNITSD': "G'S",
#    'PREFIL': '1650',
#    'PREMAX': '207.069',
#    'PREMIN': '-154.297',
#    'INSMAN': 'MFG:ENDEVCO                     S/N:BY08J       MDL:7264 ',
#    'CALDAT': '14-APR-87',
#    'INSRAT': '400',
#    'CHLMAX': '52',
#    'INIVEL': '47.5',
#    'NFP': '-160',
#    'NLP': '2721',
#    'DELT': '125',
#    'DASTAT': 'AM',
#    'SCFCTR': '1',
#    'CHSTATD': 'PRIMARY',
#    'INSCOM': 'NO COMMENTS',
#    'XTYPE': 'TIME',
#    'YTYPE': 'ACCELERATION',
#    'SIGNALNAME': 'v01050_018aa0.uds',
#    'URL_UDS': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=18&database=v&name=v01050_018aa0.uds&format=uds_single',
#    'URL_TSV': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=18&database=v&name=v01050_018aa0.uds&format=tsv_single'},
#   {'CURVE': '19',
#    'TSTNO': '1050',
#    'VEHNO': '1',
#    'SENTYPD': 'ACCELEROMETER',
#    'SENLOCD': 'NOT APPLICABLE',
#    'SENATTD': 'ENGINE',
#    'AXISD': 'X - GLOBAL',
#    'XUNITSD': 'SECONDS',
#    'YUNITSD': "G'S",
#    'PREFIL': '1650',
#    'PREMAX': '169.277',
#    'PREMIN': '-198.083',
#    'INSMAN': 'MFG:ENDEVCO                     S/N:BY24J       MDL:7264 ',
#    'CALDAT': '14-APR-87',
#    'INSRAT': '1129',
#    'CHLMAX': '18',
#    'INIVEL': '47.5',
#    'NFP': '-160',
#    'NLP': '2721',
#    'DELT': '125',
#    'DASTAT': 'AM',
#    'SCFCTR': '1',
#    'CHSTATD': 'PRIMARY',
#    'INSCOM': 'NO COMMENTS',
#    'XTYPE': 'TIME',
#    'YTYPE': 'ACCELERATION',
#    'SIGNALNAME': 'v01050_019aa0.uds',
#    'URL_UDS': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=19&database=v&name=v01050_019aa0.uds&format=uds_single',
#    'URL_TSV': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=19&database=v&name=v01050_019aa0.uds&format=tsv_single'},
#   {'CURVE': '20',
#    'TSTNO': '1050',
#    'VEHNO': '1',
#    'SENTYPD': 'ACCELEROMETER',
#    'SENLOCD': 'NOT APPLICABLE',
#    'SENATTD': 'ENGINE',
#    'AXISD': 'X - GLOBAL',
#    'XUNITSD': 'SECONDS',
#    'YUNITSD': "G'S",
#    'PREFIL': '1650',
#    'PREMAX': '329.32',
#    'PREMIN': '-391.552',
#    'INSMAN': 'MFG:ENDEVCO                     S/N:BW81J       MDL:7264 ',
#    'CALDAT': '14-APR-87',
#    'INSRAT': '993',
#    'CHLMAX': '39',
#    'INIVEL': '47.5',
#    'NFP': '-160',
#    'NLP': '2721',
#    'DELT': '125',
#    'DASTAT': 'AM',
#    'SCFCTR': '1',
#    'CHSTATD': 'PRIMARY',
#    'INSCOM': 'NO COMMENTS',
#    'XTYPE': 'TIME',
#    'YTYPE': 'ACCELERATION',
#    'SIGNALNAME': 'v01050_020aa0.uds',
#    'URL_UDS': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=20&database=v&name=v01050_020aa0.uds&format=uds_single',
#    'URL_TSV': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=20&database=v&name=v01050_020aa0.uds&format=tsv_single'},
#   {'CURVE': '21',
#    'TSTNO': '1050',
#    'VEHNO': '1',
#    'SENTYPD': 'ACCELEROMETER',
#    'SENLOCD': 'NOT APPLICABLE',
#    'SENATTD': 'BRAKE CALIPER - RIGHT',
#    'AXISD': 'X - GLOBAL',
#    'XUNITSD': 'SECONDS',
#    'YUNITSD': "G'S",
#    'PREFIL': '1650',
#    'PREMAX': '96.516',
#    'PREMIN': '-118.186',
#    'INSMAN': 'MFG:ENDEVCO                     S/N:BP79J       MDL:7264 ',
#    'CALDAT': '14-APR-87',
#    'INSRAT': '1036',
#    'CHLMAX': '11',
#    'INIVEL': '47.5',
#    'NFP': '-160',
#    'NLP': '2721',
#    'DELT': '125',
#    'DASTAT': 'AM',
#    'SCFCTR': '1',
#    'CHSTATD': 'PRIMARY',
#    'INSCOM': 'NO COMMENTS',
#    'XTYPE': 'TIME',
#    'YTYPE': 'ACCELERATION',
#    'SIGNALNAME': 'v01050_021aa0.uds',
#    'URL_UDS': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=21&database=v&name=v01050_021aa0.uds&format=uds_single',
#    'URL_TSV': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=21&database=v&name=v01050_021aa0.uds&format=tsv_single'},
#   {'CURVE': '22',
#    'TSTNO': '1050',
#    'VEHNO': '1',
#    'SENTYPD': 'ACCELEROMETER',
#    'SENLOCD': 'NOT APPLICABLE',
#    'SENATTD': 'BRAKE CALIPER - LEFT',
#    'AXISD': 'X - GLOBAL',
#    'XUNITSD': 'SECONDS',
#    'YUNITSD': "G'S",
#    'PREFIL': '1650',
#    'PREMAX': '79.2299',
#    'PREMIN': '-95.1303',
#    'INSMAN': 'MFG:ENDEVCO                     S/N:BK28J       MDL:7264 ',
#    'CALDAT': '14-APR-87',
#    'INSRAT': '1079',
#    'CHLMAX': '9',
#    'INIVEL': '47.5',
#    'NFP': '-160',
#    'NLP': '2721',
#    'DELT': '125',
#    'DASTAT': 'AM',
#    'SCFCTR': '1',
#    'CHSTATD': 'PRIMARY',
#    'INSCOM': 'NO COMMENTS',
#    'XTYPE': 'TIME',
#    'YTYPE': 'ACCELERATION',
#    'SIGNALNAME': 'v01050_022aa0.uds',
#    'URL_UDS': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=22&database=v&name=v01050_022aa0.uds&format=uds_single',
#    'URL_TSV': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=22&database=v&name=v01050_022aa0.uds&format=tsv_single'},
#   {'CURVE': '23',
#    'TSTNO': '1050',
#    'VEHNO': '1',
#    'SENTYPD': 'ACCELEROMETER',
#    'SENLOCD': 'NOT APPLICABLE',
#    'SENATTD': 'DASHPANEL - CENTER',
#    'AXISD': 'X - GLOBAL',
#    'XUNITSD': 'SECONDS',
#    'YUNITSD': "G'S",
#    'PREFIL': '1650',
#    'PREMAX': '29.3451',
#    'PREMIN': '-60.904',
#    'INSMAN': 'MFG:ENDEVCO                     S/N:BK86J       MDL:7264 ',
#    'CALDAT': '14-APR-87',
#    'INSRAT': '461',
#    'CHLMAX': '13',
#    'INIVEL': '47.5',
#    'NFP': '-160',
#    'NLP': '2721',
#    'DELT': '125',
#    'DASTAT': 'AM',
#    'SCFCTR': '1',
#    'CHSTATD': 'PRIMARY',
#    'INSCOM': 'NO COMMENTS',
#    'XTYPE': 'TIME',
#    'YTYPE': 'ACCELERATION',
#    'SIGNALNAME': 'v01050_023aa0.uds',
#    'URL_UDS': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=23&database=v&name=v01050_023aa0.uds&format=uds_single',
#    'URL_TSV': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=23&database=v&name=v01050_023aa0.uds&format=tsv_single'}],
#  'VIDEOS': [],
#  'PHOTOS': [],
#  'REPORTS': [{'REPNO': '1',
#    'ORIG_FILENAME': '',
#    'FILENAME': 'v01050R001.pdf',
#    'FILESIZE': '4396998',
#    'URL': 'https://www-nrd.nhtsa.dot.gov/database/MEDIA/GetMedia.aspx?tstno=1050&index=1&database=V&type=R'}]}

# %%
len(json_data)
# Out:
# 10

# %%
a = json_data.values()

# %%
json_data['TEST']
# Out:
# {'TSTNO': '1050',
#  'VERNO': '2 ',
#  'TITLE': '1987 BUICK LESABRE INTO FRONTAL BARRIER',
#  'TSTOBJ': '30 MPH FRONTAL BARRIER IMPACT 208,212,219(PARTIAL,& 301-75 COMPLIANCE ',
#  'TSTDAT': '13-JUL-87',
#  'TSTPRFD': 'TRC OF OHIO',
#  'CONNO': 'DTNH22-87-C-01024',
#  'TSTREF': '870713',
#  'TSTTYPD': 'FMVSS 208 OCCUPANT CRASH PROTECTION',
#  'TSTCFND': 'VEHICLE INTO BARRIER',
#  'TKSURFD': 'CONCRETE',
#  'TKCOND': 'DRY',
#  'TEMP': '31',
#  'RECTYPD': 'FM MULTIPLEXOR TAPE RECORDER',
#  'LINK': 'UMB',
#  'CLSSPD': '47.5',
#  'IMPANG': '0',
#  'OFFSET': '0',
#  'IMPPNT': '',
#  'MEASURD': 'ENGLISH',
#  'TOTCRV': '23',
#  'TSTCOM': 'NO COMMENTS'}

# %%
b = json_data.keys()

# %%
b
# Out:
# dict_keys(['TEST', 'VEHICLE', 'BARRIER', 'OCCUPANT', 'RESTRAINT', 'URL', 'INSTRUMENTATION', 'VIDEOS', 'PHOTOS', 'REPORTS'])

# %%
list(b)
# Out:
# ['TEST',
#  'VEHICLE',
#  'BARRIER',
#  'OCCUPANT',
#  'RESTRAINT',
#  'URL',
#  'INSTRUMENTATION',
#  'VIDEOS',
#  'PHOTOS',
#  'REPORTS']

# %%
json_data['RESTRAINT'][0]
# Out:
# {'RSTNO': '1',
#  'VEHNO': '1',
#  'OCCLOCD': 'LEFT FRONT SEAT',
#  'RSTTYPD': 'PASSIVE 3 POINT BELT',
#  'RSTMNTD': '',
#  'DEPLOYD': 'NOT APPLICABLE',
#  'RSTCOM': 'NO COMMENTS '}

# %%
json_data['RESTRAINT'][1]
# Out:
# {'RSTNO': '1',
#  'VEHNO': '1',
#  'OCCLOCD': 'RIGHT FRONT SEAT',
#  'RSTTYPD': 'PASSIVE 3 POINT BELT',
#  'RSTMNTD': '',
#  'DEPLOYD': 'NOT APPLICABLE',
#  'RSTCOM': 'NO COMMENTS '}

# %%
for i in list(b):
    print('='*50)
    print(i)
    print('\n')
    print(json_data[i])
    print('\n')
# Out:
# ==================================================
# TEST
#
#
# {'TSTNO': '1050', 'VERNO': '2 ', 'TITLE': '1987 BUICK LESABRE INTO FRONTAL BARRIER', 'TSTOBJ': '30 MPH FRONTAL BARRIER IMPACT 208,212,219(PARTIAL,& 301-75 COMPLIANCE ', 'TSTDAT': '13-JUL-87', 'TSTPRFD': 'TRC OF OHIO', 'CONNO': 'DTNH22-87-C-01024', 'TSTREF': '870713', 'TSTTYPD': 'FMVSS 208 OCCUPANT CRASH PROTECTION', 'TSTCFND': 'VEHICLE INTO BARRIER', 'TKSURFD': 'CONCRETE', 'TKCOND': 'DRY', 'TEMP': '31', 'RECTYPD': 'FM MULTIPLEXOR TAPE RECORDER', 'LINK': 'UMB', 'CLSSPD': '47.5', 'IMPANG': '0', 'OFFSET': '0', 'IMPPNT': '', 'MEASURD': 'ENGLISH', 'TOTCRV': '23', 'TSTCOM': 'NO COMMENTS'}
#
#
# ==================================================
# VEHICLE
#
#
# [{'VEHNO': '1', 'MAKED': 'BUICK', 'MODELD': 'LESABRE', 'YEAR': '1987', 'BODYD': 'TWO DOOR SEDAN', 'VIN': '1G4HP1437HH454361', 'ENGINED': 'STRAIGHT 6 TRANSVERSE FRONT', 'ENGDSP': '3.8', 'TRANSMD': 'AUTOMATIC - FRONT WHEEL DRIVE', 'VEHTWT': '1693', 'WHLBAS': '2817', 'VEHLEN': '4999', 'VEHWID': '1819', 'VEHCG': '1143', 'STRSEPD': 'UNKNOWN', 'COLMECD': 'NOT APPLICABLE', 'MODINDD': 'PRODUCTION VEHICLE', 'MODDSC': 'NO COMMENTS ', 'BX1': '4999', 'BX2': '4397', 'BX3': '3736', 'BX4': '3320', 'BX5': '3322', 'BX6': '3322', 'BX7': '3312', 'BX8': '1928', 'BX9': '1928', 'BX10': '1905', 'BX11': '1902', 'BX12': '3297', 'BX13': '3292', 'BX14': '3571', 'BX15': '3637', 'BX16': '2883', 'BX17': '381', 'BX18': '422', 'BX19': '4877', 'BX20': '4872', 'BX21': '572', 'VEHSPD': '47.5', 'CRBANG': '0', 'PDOF': '0', 'BMPENGD': 'NOT APPLICABLE', 'SILENGD': 'NOT APPLICABLE', 'APLENGD': 'NOT APPLICABLE', 'DPD1': '617', 'DPD2': '660', 'DPD3': '650', 'DPD4': '688', 'DPD5': '663', 'DPD6': '622', 'VDI': '12FDEW3', 'LENCNT': '1666', 'DAMDST': '0', 'CRHDST': '693', 'AX1': '4305', 'AX2': '4176', 'AX3': '3696', 'AX4': '3325', 'AX5': '3325', 'AX6': '3315', 'AX7': '3307', 'AX8': '1930', 'AX9': '1933', 'AX10': '1905', 'AX11': '1900', 'AX12': '3272', 'AX13': '3279', 'AX14': '3533', 'AX15': '3607', 'AX16': '2873', 'AX17': '361', 'AX18': '401', 'AX19': '4255', 'AX20': '4255', 'AX21': '572', 'CARANG': '', 'VEHOR': '', 'VEHCOM': "STEERING COLUMN COLLAPSE MECHANISM UNDER DASH, COULDN'T BE SEEN"}]
#
#
# ==================================================
# BARRIER
#
#
# {'BARRIGD': 'RIGID', 'BARSHPD': 'FLAT BARRIER', 'BARANG': '0', 'BARDIA': '', 'BARID': '', 'BARCOM': 'NO COMMENTS'}
#
#
# ==================================================
# OCCUPANT
#
#
# [{'OCCLOC': '01', 'VEHNO': '1', 'OCCTYPD': 'PART 572 DUMMY', 'OCCAGE': '', 'OCCSEXD': 'MALE', 'OCCHT': '', 'OCCWT': '', 'MTHCALD': 'PART 572', 'DUMSIZD': '50 PERCENTILE', 'DUMMAN': 'MFG: ALDERSON RESEARCH LABS; S/N 758 ', 'DUMMOD': 'UNMODIFIED ', 'DUMDSC': 'PART 572B CALIBRATION ', 'HH': '434', 'HW': '564', 'HR': '224', 'HS': '318', 'CD': '640', 'CS': '396', 'AD': '168', 'HD': '140', 'KD': '140', 'HB': '', 'NB': '', 'CB': '', 'KB': '', 'SEPOSN': 'CN', 'CNTRH1D': 'STEERING WHEEL', 'CNTRH2D': 'NONE', 'CNTRC1D': 'STEERING WHEEL', 'CNTRC2D': 'NONE', 'CNTRL1D': 'DASHPANEL', 'CNTRL2D': 'NONE', 'HIC': '664', 'T1': '86.75', 'T2': '121.13', 'CLIP3M': '35.1', 'LFEM': '-5009', 'RFEM': '-3928', 'CSI': '218', 'LBELT': '', 'SBELT': '', 'TTI': '', 'PELVG': '', 'OCCCOM': 'NO COMMENTS'}, {'OCCLOC': '02', 'VEHNO': '1', 'OCCTYPD': 'PART 572 DUMMY', 'OCCAGE': '', 'OCCSEXD': 'MALE', 'OCCHT': '', 'OCCWT': '', 'MTHCALD': 'PART 572', 'DUMSIZD': '50 PERCENTILE', 'DUMMAN': 'MFG: ALDERSON RESEARCH LABS; S/N 690 ', 'DUMMOD': 'UNMODIFIED ', 'DUMDSC': 'PART 572B CALIBRATION ', 'HH': '442', 'HW': '599', 'HR': '193', 'HS': '300', 'CD': '577', 'CS': '', 'AD': '142', 'HD': '122', 'KD': '191', 'HB': '', 'NB': '', 'CB': '', 'KB': '', 'SEPOSN': 'CN', 'CNTRH1D': 'NONE', 'CNTRH2D': 'NONE', 'CNTRC1D': 'NONE', 'CNTRC2D': 'NONE', 'CNTRL1D': 'DASHPANEL', 'CNTRL2D': 'NONE', 'HIC': '366', 'T1': '96.38', 'T2': '132.38', 'CLIP3M': '29.8', 'LFEM': '-3261', 'RFEM': '-2700', 'CSI': '212', 'LBELT': '', 'SBELT': '', 'TTI': '', 'PELVG': '', 'OCCCOM': 'NO COMMENTS'}]
#
#
# ==================================================
# RESTRAINT
#
#
# [{'RSTNO': '1', 'VEHNO': '1', 'OCCLOCD': 'LEFT FRONT SEAT', 'RSTTYPD': 'PASSIVE 3 POINT BELT', 'RSTMNTD': '', 'DEPLOYD': 'NOT APPLICABLE', 'RSTCOM': 'NO COMMENTS '}, {'RSTNO': '1', 'VEHNO': '1', 'OCCLOCD': 'RIGHT FRONT SEAT', 'RSTTYPD': 'PASSIVE 3 POINT BELT', 'RSTMNTD': '', 'DEPLOYD': 'NOT APPLICABLE', 'RSTCOM': 'NO COMMENTS '}, {'RSTNO': '2', 'VEHNO': '1', 'OCCLOCD': 'RIGHT FRONT SEAT', 'RSTTYPD': 'DASHPANEL', 'RSTMNTD': '', 'DEPLOYD': 'NOT APPLICABLE', 'RSTCOM': 'NO COMMENTS '}]
#
#
# ==================================================
# URL
#
#
# {'URL_UDS': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=&database=v&name=v01050&format=uds', 'URL_EV5': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=&database=v&name=v01050&format=ev5', 'URL_ABF': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=&database=v&name=v01050&format=abf', 'URL_ISO': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=&database=v&name=v01050&format=iso', 'URL_TDMS': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=&database=v&name=v01050&format=tdms'}
#
#
# ==================================================
# INSTRUMENTATION
#
#
# [{'CURVE': '1', 'TSTNO': '1050', 'VEHNO': '1', 'SENTYPD': 'ACCELEROMETER', 'SENLOCD': 'LEFT FRONT SEAT', 'SENATTD': 'HEAD CG', 'AXISD': 'X - LOCAL', 'XUNITSD': 'SECONDS', 'YUNITSD': "G'S", 'PREFIL': '1650', 'PREMAX': '32.3339', 'PREMIN': '-110.537', 'INSMAN': 'MFG:ENDEVCO                     S/N:BY27J       MDL:7264 ', 'CALDAT': '14-APR-87', 'INSRAT': '466', 'CHLMAX': '24', 'INIVEL': '47.5', 'NFP': '-160', 'NLP': '2721', 'DELT': '125', 'DASTAT': 'AM', 'SCFCTR': '1', 'CHSTATD': 'PRIMARY', 'INSCOM': 'NO COMMENTS', 'XTYPE': 'TIME', 'YTYPE': 'ACCELERATION', 'SIGNALNAME': 'v01050_001aa0.uds', 'URL_UDS': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=1&database=v&name=v01050_001aa0.uds&format=uds_single', 'URL_TSV': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=1&database=v&name=v01050_001aa0.uds&format=tsv_single'}, {'CURVE': '2', 'TSTNO': '1050', 'VEHNO': '1', 'SENTYPD': 'ACCELEROMETER', 'SENLOCD': 'LEFT FRONT SEAT', 'SENATTD': 'HEAD CG', 'AXISD': 'Y - LOCAL', 'XUNITSD': 'SECONDS', 'YUNITSD': "G'S", 'PREFIL': '1650', 'PREMAX': '36.5295', 'PREMIN': '-10.0741', 'INSMAN': 'MFG:ENDEVCO                     S/N:BI18J       MDL:7264 ', 'CALDAT': '14-APR-87', 'INSRAT': '444', 'CHLMAX': '8', 'INIVEL': '0', 'NFP': '-160', 'NLP': '2721', 'DELT': '125', 'DASTAT': 'AM', 'SCFCTR': '1', 'CHSTATD': 'PRIMARY', 'INSCOM': 'NO COMMENTS', 'XTYPE': 'TIME', 'YTYPE': 'ACCELERATION', 'SIGNALNAME': 'v01050_002aa0.uds', 'URL_UDS': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=2&database=v&name=v01050_002aa0.uds&format=uds_single', 'URL_TSV': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=2&database=v&name=v01050_002aa0.uds&format=tsv_single'}, {'CURVE': '3', 'TSTNO': '1050', 'VEHNO': '1', 'SENTYPD': 'ACCELEROMETER', 'SENLOCD': 'LEFT FRONT SEAT', 'SENATTD': 'HEAD CG', 'AXISD': 'Z - LOCAL', 'XUNITSD': 'SECONDS', 'YUNITSD': "G'S", 'PREFIL': '1650', 'PREMAX': '15.8832', 'PREMIN': '-86.5231', 'INSMAN': 'MFG:ENDEVCO                     S/N:BP89J       MDL:7264 ', 'CALDAT': '14-APR-87', 'INSRAT': '459', 'CHLMAX': '19', 'INIVEL': '0', 'NFP': '-160', 'NLP': '2721', 'DELT': '125', 'DASTAT': 'AM', 'SCFCTR': '1', 'CHSTATD': 'PRIMARY', 'INSCOM': 'NO COMMENTS', 'XTYPE': 'TIME', 'YTYPE': 'ACCELERATION', 'SIGNALNAME': 'v01050_003aa0.uds', 'URL_UDS': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=3&database=v&name=v01050_003aa0.uds&format=uds_single', 'URL_TSV': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=3&database=v&name=v01050_003aa0.uds&format=tsv_single'}, {'CURVE': '4', 'TSTNO': '1050', 'VEHNO': '1', 'SENTYPD': 'ACCELEROMETER', 'SENLOCD': 'LEFT FRONT SEAT', 'SENATTD': 'CHEST', 'AXISD': 'X - LOCAL', 'XUNITSD': 'SECONDS', 'YUNITSD': "G'S", 'PREFIL': '1650', 'PREMAX': '8.2487', 'PREMIN': '-38.473', 'INSMAN': 'MFG:ENDEVCO                     S/N:BI08J       MDL:7264 ', 'CALDAT': '14-APR-87', 'INSRAT': '439', 'CHLMAX': '9', 'INIVEL': '47.5', 'NFP': '-160', 'NLP': '2721', 'DELT': '125', 'DASTAT': 'AM', 'SCFCTR': '1', 'CHSTATD': 'PRIMARY', 'INSCOM': 'NO COMMENTS', 'XTYPE': 'TIME', 'YTYPE': 'ACCELERATION', 'SIGNALNAME': 'v01050_004aa0.uds', 'URL_UDS': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=4&database=v&name=v01050_004aa0.uds&format=uds_single', 'URL_TSV': 'https://www-nrd.nhtsa.dot.gov/database/VSR/Download.aspx?tstno=1050&curno=4&database=v&name=v01050_004aa0.uds&format=tsv_single'}, {'CURVE': '5', 'TSTNO': '1050', 'VEHNO': '1', 'SENTYPD': 'ACCELEROMETER', 'SENLOCD': 'LEFT FRONT SEAT', 'SENATTD': 'CHEST', 'AXISD': 'Y - LOCAL', 'XUNITSD': 'SECONDS', 'YUNITSD': "G'S", 'PREFIL': '1650', 'PREMAX': '13.0851', 'PREMIN': '-6.36484', 'INSMAN': 'MFG:ENDEVCO                     S/N:BG58J       MDL:7264 ', 'CALDAT': '14-APR-87', 'INSRAT': '480', 'CHLMAX': '3', 'INIVEL': '0', 'NFP': '-160', 'NLP': '2721', 'DELT': '125', 'DASTAT': 'AM', 'SCFCTR': '1', 'CHSTATD': 'PRIMARY', 'INSCOM': ...
#
#
# ==================================================
# VIDEOS
#
#
# []
#
#
# ==================================================
# PHOTOS
#
#
# []
#
#
# ==================================================
# REPORTS
#
#
# [{'REPNO': '1', 'ORIG_FILENAME': '', 'FILENAME': 'v01050R001.pdf', 'FILESIZE': '4396998', 'URL': 'https://www-nrd.nhtsa.dot.gov/database/MEDIA/GetMedia.aspx?tstno=1050&index=1&database=V&type=R'}]

# %%
import pandas as pd

df_json = pd.DataFrame(data=a, columns=b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-bfd3a913a844> in <module>
#       1 import pandas as pd
#       2
# ----> 3 df_json = pd.DataFrame(data=a, columns=b)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     568                     if is_named_tuple(data[0]) and columns is None:
#     569                         columns = data[0]._fields
# --> 570                     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     571                     columns = ensure_index(columns)
#     572
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/construction.py in to_arrays(data, columns, coerce_float, dtype)
#     528         return _list_to_arrays(data, columns, coerce_float=coerce_float, dtype=dtype)
#     529     elif isinstance(data[0], abc.Mapping):
# --> 530         return _list_of_dict_to_arrays(
#     531             data, columns, coerce_float=coerce_float, dtype=dtype
#     532         )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/construction.py in _list_of_dict_to_arrays(data, columns, coerce_float, dtype)
#     645     # assure that they are of the base dict class and not of derived
#     646     # classes
# --> 647     data = [(type(d) is dict) and d or dict(d) for d in data]
#     648
#     649     content = list(lib.dicts_to_array(data, list(columns)).T)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/construction.py in <listcomp>(.0)
#     645     # assure that they are of the base dict class and not of derived
#     646     # classes
# --> 647     data = [(type(d) is dict) and d or dict(d) for d in data]
#     648
#     649     content = list(lib.dicts_to_array(data, list(columns)).T)
#
# ValueError: dictionary update sequence element #0 has length 79; 2 is required

# %%
df_test = pd.DataFrame(data=json_data['VEHICLE'])
df_test
# Out:
#   VEHNO  MAKED   MODELD  YEAR           BODYD                VIN  \
# 0     1  BUICK  LESABRE  1987  TWO DOOR SEDAN  1G4HP1437HH454361
#
#                        ENGINED ENGDSP                        TRANSMD VEHTWT  \
# 0  STRAIGHT 6 TRANSVERSE FRONT    3.8  AUTOMATIC - FRONT WHEEL DRIVE   1693
#
#    ...  AX15  AX16 AX17 AX18  AX19  AX20 AX21 CARANG VEHOR  \
# 0  ...  3607  2873  361  401  4255  4255  572
#
#                                               VEHCOM
# 0  STEERING COLUMN COLLAPSE MECHANISM UNDER DASH,...
#
# [1 rows x 79 columns]

# %%
df_test = pd.DataFrame(data=json_data['RESTRAINT'])
df_test
# Out:
#   RSTNO VEHNO           OCCLOCD               RSTTYPD RSTMNTD         DEPLOYD  \
# 0     1     1   LEFT FRONT SEAT  PASSIVE 3 POINT BELT          NOT APPLICABLE
# 1     1     1  RIGHT FRONT SEAT  PASSIVE 3 POINT BELT          NOT APPLICABLE
# 2     2     1  RIGHT FRONT SEAT             DASHPANEL          NOT APPLICABLE
#
#          RSTCOM
# 0  NO COMMENTS
# 1  NO COMMENTS
# 2  NO COMMENTS

# %%
df_test = pd.DataFrame(data=json_data['INSTRUMENTATION'])
df_test
# Out:
#    CURVE TSTNO VEHNO        SENTYPD           SENLOCD                SENATTD  \
# 0      1  1050     1  ACCELEROMETER   LEFT FRONT SEAT                HEAD CG
# 1      2  1050     1  ACCELEROMETER   LEFT FRONT SEAT                HEAD CG
# 2      3  1050     1  ACCELEROMETER   LEFT FRONT SEAT                HEAD CG
# 3      4  1050     1  ACCELEROMETER   LEFT FRONT SEAT                  CHEST
# 4      5  1050     1  ACCELEROMETER   LEFT FRONT SEAT                  CHEST
# 5      6  1050     1  ACCELEROMETER   LEFT FRONT SEAT                  CHEST
# 6      7  1050     1      LOAD CELL   LEFT FRONT SEAT           FEMUR - LEFT
# 7      8  1050     1      LOAD CELL   LEFT FRONT SEAT          FEMUR - RIGHT
# 8      9  1050     1  ACCELEROMETER  RIGHT FRONT SEAT                HEAD CG
# 9     10  1050     1  ACCELEROMETER  RIGHT FRONT SEAT                HEAD CG
# 10    11  1050     1  ACCELEROMETER  RIGHT FRONT SEAT                HEAD CG
# 11    12  1050     1  ACCELEROMETER  RIGHT FRONT SEAT                  CHEST
# 12    13  1050     1  ACCELEROMETER  RIGHT FRONT SEAT                  CHEST
# 13    14  1050     1  ACCELEROMETER  RIGHT FRONT SEAT                  CHEST
# 14    15  1050     1      LOAD CELL  RIGHT FRONT SEAT           FEMUR - LEFT
# 15    16  1050     1      LOAD CELL  RIGHT FRONT SEAT          FEMUR - RIGHT
# 16    17  1050     1  ACCELEROMETER    NOT APPLICABLE       SEAT - LEFT REAR
# 17    18  1050     1  ACCELEROMETER    NOT APPLICABLE      SEAT - RIGHT REAR
# 18    19  1050     1  ACCELEROMETER    NOT APPLICABLE                 ENGINE
# 19    20  1050     1  ACCELEROMETER    NOT APPLICABLE                 ENGINE
# 20    21  1050     1  ACCELEROMETER    NOT APPLICABLE  BRAKE CALIPER - RIGHT
# 21    22  1050     1  ACCELEROMETER    NOT APPLICABLE   BRAKE CALIPER - LEFT
# 22    23  1050     1  ACCELEROMETER    NOT APPLICABLE     DASHPANEL - CENTER
#
#          AXISD  XUNITSD  YUNITSD PREFIL  ... DELT DASTAT SCFCTR  CHSTATD  \
# 0    X - LOCAL  SECONDS      G'S   1650  ...  125     AM      1  PRIMARY
# 1    Y - LOCAL  SECONDS      G'S   1650  ...  125     AM      1  PRIMARY
# 2    Z - LOCAL  SECONDS      G'S   1650  ...  125     AM      1  PRIMARY
# 3    X - LOCAL  SECONDS      G'S   1650  ...  125     AM      1  PRIMARY
# 4    Y - LOCAL  SECONDS      G'S   1650  ...  125     AM      1  PRIMARY
# 5    Z - LOCAL  SECONDS      G'S   1650  ...  125     AM      1  PRIMARY
# 6    Z - LOCAL  SECONDS  NEWTONS   1650  ...  125     AM      1  PRIMARY
# 7    Z - LOCAL  SECONDS  NEWTONS   1650  ...  125     AM      1  PRIMARY
# 8    X - LOCAL  SECONDS      G'S   1650  ...  125     AM      1  PRIMARY
# 9    Y - LOCAL  SECONDS      G'S   1650  ...  125     AM      1  PRIMARY
# 10   Z - LOCAL  SECONDS      G'S   1650  ...  125     AM      1  PRIMARY
# 11   X - LOCAL  SECONDS      G'S   1650  ...  125     AM      1  PRIMARY
# 12   Y - LOCAL  SECONDS      G'S   1650  ...  125     AM      1  PRIMARY
# 13   Z - LOCAL  SECONDS      G'S   1650  ...  125     AM      1  PRIMARY
# 14   Z - LOCAL  SECONDS  NEWTONS   1650  ...  125     AM      1  PRIMARY
# 15   Z - LOCAL  SECONDS  NEWTONS   1650  ...  125     AM      1  PRIMARY
# 16  X - GLOBAL  SECONDS      G'S   1650  ...  125     AM      1  PRIMARY
# 17  X - GLOBAL  SECONDS      G'S   1650  ...  125     AM      1  PRIMARY
# 18  X - GLOBAL  SECONDS      G'S   1650  ...  125     AM      1  PRIMARY
# 19  X - GLOBAL  SECONDS      G'S   1650  ...  125     AM      1  PRIMARY
# 20  X - GLOBAL  SECONDS      G'S   1650  ...  125     AM      1  PRIMARY
# 21  X - GLOBAL  SECONDS      G'S   1650  ...  125     AM      1  PRIMARY
# 22  X - GLOBAL  SECONDS      G'S   1650  ...  125     AM      1  PRIMARY
#
#          INSCOM XTYPE         YTYPE         SIGNALNAME  \
# 0   NO COMMENTS  TIME  ACCELERATION  v01050_001aa0.uds
# 1   NO COMMENTS  TIME  ACCELERATION  v01050_002aa0.uds
# 2   NO COMMENTS  TIME  ACCELERATION  v01050_003aa0.uds
# 3   NO COMMENTS  TIME  ACCELERATION  v01050_004aa0.uds
# 4   NO COMMENTS  TIME  ACCELERATION  v01050_005aa0.uds
# 5   NO COMMENTS  TIME  ACCELERATION  v01050_006aa0.uds
# 6   NO COMMENTS  TIME         FORCE  v01050_007fa0.uds
# 7   NO COMMENTS  TIME         FORCE  v01050_008fa0.uds
# 8   NO COMMENTS  TIME  ACCELERATION  v01050_009aa0.uds
# 9   NO COMMENTS  TIME  ACCELERATION  v01050_010aa0.uds
# 10  NO COMMENTS  TIME  ACCELERATION  v01050_011aa0.uds
# 11  NO COMMENTS  TIME  ACCELERATION  v01050_012aa0.uds
# 12  NO COMMENTS  TIME  ACCELERATION  v01050_013aa0.uds
# 13  NO COMMENTS  TIME  ACCELERATION  v01050_014aa0.uds
# 14  NO COMMENTS  TIME         FORCE  v01050_015fa0.uds
# 15  NO COMMENTS  TIME         FORCE  v01050_016fa0.uds
# 16  NO COMMENTS  TIME  ACCELERATION  v01050_017aa0.uds
# 17  NO COMMENTS  TIME  ACCELERATION  v01050_018aa0.uds
# 18  NO COMMENTS  TIME  ACCELERATION  v01050_019aa0.uds
# 19  NO COMMENTS  TIME  ACCELERATION  v01050_020aa0.uds
# 20  NO COMMENTS  TIME  ACCELERATION  v01050_021aa0.uds
# 21  NO COMMENTS  TIME  ACCELERATION  v01050_022aa0.uds
# 22  NO COMMENTS  TIME  ACCELERATION  v01050_023aa0.uds
#
#                                               URL_UDS  \
# 0   https://www-nrd.nhtsa.dot.gov/database/VSR/Dow...
# 1   https://www-nrd.nhtsa.dot.gov/database/VSR/Dow...
# 2   https://www-nrd.nhtsa.dot.gov/database/VSR/Dow...
# 3   https://www-nrd.nhtsa.dot.gov/database/VSR/Dow...
# 4   https://www-nrd.nhtsa.dot.gov/database/VSR/Dow...
# 5   https://www-nrd.nhtsa.dot.gov/database/VSR/Dow...
# 6   https://www-nrd.nhtsa.dot.gov/database/VSR/Dow...
# 7   https://www-nrd.nhtsa.dot.gov/database/VSR/Dow...
# 8   https://www-nrd.nhtsa.dot.gov/database/VSR/Dow...
# 9   https://www-nrd.nhtsa.dot.gov/database/VSR/Dow...
# 10  https://www-nrd.nhtsa.dot.gov/database/VSR/Dow...
# 11  https://www-nrd.nhtsa.dot.gov/database/VSR/Dow...
# 12  https://www-nrd.nhtsa.dot.gov/database/VSR/Dow...
# 13  https://www-nrd.nhtsa.dot.gov/database/VSR/Dow...
# 14  https://www-nrd.nhtsa.dot.gov/database/VSR/Dow...
# 15  https://www-nrd.nhtsa.dot.gov/database/VSR/Dow...
# 16  https://www-nrd.nhtsa.dot.gov/database/VSR/Dow...
# 17  https://www-nrd.nhtsa.dot.gov/database/VSR/Dow...
# 18  https://www-nrd.nhtsa.dot.gov/database/VSR/Dow...
# 19  https://www-nrd.nhtsa.dot.gov/database/VSR/Dow...
# 20  https://www-nrd.nhtsa.dot.gov/database/VSR/Dow...
# 21  https://www-nrd.nhtsa.dot.gov/database/VSR/Dow...
# 22  https://www-nrd.nhtsa.dot.gov/database/VSR/Dow...
#
#                                               URL_TSV
# 0   https://www-nrd.nhtsa.dot.gov/database/VSR/Dow...
# 1   https://www-nrd.nhtsa.dot.gov/database/VSR/Dow...
# 2   https://www-nrd.nhtsa.dot.gov/database/VSR/Dow...
# 3   https://www-nrd.nhtsa.dot.gov/database/VSR/Dow...
# 4   https://www-nrd.nhtsa.dot.gov/database/VSR/Dow...
# 5   https://www-nrd.nhtsa.dot.gov/database/VSR/Dow...
# 6   https://www-nrd.nhtsa.dot.gov/database/VSR/Dow...
# 7   https://www-nrd.nhtsa.dot.gov/database/VSR/Dow...
# 8   https://www-nrd.nhtsa.dot.gov/database/VSR/Dow...
# 9   https://www-nrd.nhtsa.dot.gov/database/VSR/Dow...
# 10  https://www-nrd.nhtsa.dot.gov/database/VSR/Dow...
# 11  https://www-nrd.nhtsa.dot.gov/database/VSR/Dow...
# 12  https://www-nrd.nhtsa.dot.gov/database/VSR/Dow...
# 13  https://www-nrd.nhtsa.dot.gov/database/VSR/Dow...
# 14  https://www-nrd.nhtsa.dot.gov/database/VSR/Dow...
# 15  https://www-nrd.nhtsa.dot.gov/database/VSR/Dow...
# 16  https://www-nrd.nhtsa.dot.gov/database/VSR/Dow...
# 17  https://www-nrd.nhtsa.dot.gov/database/VSR/Dow...
# 18  https://www-nrd.nhtsa.dot.gov/database/VSR/Dow...
# 19  https://www-nrd.nhtsa.dot.gov/database/VSR/Dow...
# 20  https://www-nrd.nhtsa.dot.gov/database/VSR/Dow...
# 21  https://www-nrd.nhtsa.dot.gov/database/VSR/Dow...
# 22  https://www-nrd.nhtsa.dot.gov/database/VSR/Dow...
#
# [23 rows x 29 columns]

# %% [markdown]
# ---

# %%
with open('data/v11845.json') as json_file:
    json_data = json.load(json_file)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-83-3c4e189e954d> in <module>
#       1 with open('data/v11845.json') as json_file:
# ----> 2     json_data = json.load(json_file)
#
# ~/opt/anaconda3/lib/python3.8/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# ~/opt/anaconda3/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ~/opt/anaconda3/lib/python3.8/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~/opt/anaconda3/lib/python3.8/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 190 column 8 (char 3109)
